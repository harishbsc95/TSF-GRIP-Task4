# %% [markdown]
# # Task - 4 :- Datascience and Business Analytics

# %% [markdown]
# By Arcot Harish Intern at Sparks Foundation

# %% [markdown]
# Task - 4(Intermediate):-  To perform Exploratory Analysis on 'Global Terrorism' dataset

# %% [markdown]
# # Import relevant libraries

# %%
# Importing the libraries that require in this task
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Importing the dataset

# %%
#To import and read data
data = pd.read_csv('globalterrorismdb_0718dist.csv')
data.head()
# Out:
# C:\Users\haris\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
#To display total number of rows and columns of dataset
data.shape
# Out:
# (181691, 135)

# %%
#To display no of rows
data['eventid'].unique().shape
# Out:
# (181691,)

# %%
#To find information about our dataset
data.info
# Out:
# <bound method DataFrame.info of              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
# ...

# %%
#To display column names only
data.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
#To display cont in our dataset
data.count()
# Out:
# eventid       181691
# iyear         181691
# imonth        181691
# iday          181691
# approxdate      9239
#                ...
# INT_LOG       181691
# INT_IDEO      181691
# INT_MISC      181691
# INT_ANY       181691
# related        25038
# Length: 135, dtype: int64

# %%
#To check wether there are null values
data.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
#To fill null values
missing_percentage = data.isnull().sum()*100/len(data)
missing_percentage
# Out:
# eventid        0.000000
# iyear          0.000000
# imonth         0.000000
# iday           0.000000
# approxdate    94.914993
#                 ...
# INT_LOG        0.000000
# INT_IDEO       0.000000
# INT_MISC       0.000000
# INT_ANY        0.000000
# related       86.219461
# Length: 135, dtype: float64

# %%
#To plot a heatmap
plt.figure(figsize=(18,18))
sns.heatmap(data.isnull(), yticklabels=False, cbar=False, cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
#To removie missing values
data.dropna(axis=1, inplace=True)

# %%
#To display correlation
data.corr()
# Out:
#               eventid     iyear    imonth      iday  extended   country  \
# eventid      1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear        0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth       0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday         0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended     0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# country     -0.135039 -0.135023 -0.006305  0.003468 -0.020466  1.000000
# region       0.401371  0.401384 -0.002999  0.009710  0.038389  0.148597
# vicinity     0.070646  0.070659 -0.004501 -0.005367  0.017784 -0.012291
# crit1        0.002019  0.001995  0.001568  0.011434 -0.015029 -0.006646
# crit2        0.026215  0.026211  0.001734 -0.002702  0.001249 -0.038480
# crit3       -0.016789 -0.016784  0.000176 -0.004889  0.048533 -0.040288
# success     -0.082972 -0.082963 -0.002845 -0.011802  0.073233 -0.037827
# ...

# %% [markdown]
# # Visualizing the data

# %%
#To find we plot graph between no of attacks and attack year to find if there is increase in terrorism
plt.rcParams["figure.figsize"] = 15, 11
sns.countplot(x = data["iyear"])
plt.ylabel("Number of Attacks", fontsize=18)
plt.xticks(rotation=90)
plt.xlabel("Attack Year", fontsize=18)
plt.title("Increase in Terror", size=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Increase in Terror')

# %%
#To find sucess rate, we again
plt.rcParams["figure.figsize"] = 15, 11
sns.countplot(x = data["iyear"], hue="success", data=data)
plt.ylabel("Number of Attacks", fontsize=18)
plt.xticks(rotation=90)
plt.xlabel("Attack Year", fontsize=18)
plt.title("Increase in Terror", size=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Increase in Terror')

# %%
#Now we plot graph between number of attacks and attack region(comparing regionwise)
plt.rcParams["figure.figsize"] = 15, 11
sns.countplot(x = data["region_txt"])
plt.ylabel("Number of Attacks", fontsize=18)
plt.xticks(rotation=90)
plt.xlabel("Attack Year", fontsize=18)
plt.title("Attack Region", size=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Attack Region')

# %%
#To compare countrywise 
plt.rcParams["figure.figsize"] = 15, 11
sns.barplot(x = data["country_txt"].value_counts()[:20].index, y=data["country_txt"].value_counts()[:20].values)
plt.ylabel("Number of Attacks", fontsize=18)
plt.xticks(rotation=90)
plt.xlabel("Attack Region", fontsize=18)
plt.title("Country wise Attacks", size=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Country wise Attacks')

# %%
#To compare attack types
plt.rcParams["figure.figsize"] = 15, 11
sns.barplot(x = data["attacktype1_txt"].value_counts()[:20].index, y=data["attacktype1_txt"].value_counts()[:20].values)
plt.ylabel("Total Attacks", fontsize=18)
plt.xticks(rotation=90)
plt.xlabel("Attack Type", fontsize=18)
plt.title("Attack Type", size=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Attack Type')

# %%
#To compare between groups
plt.rcParams["figure.figsize"] = 15, 11
sns.barplot(x = data["gname"].value_counts()[:20].index, y=data["gname"].value_counts()[:20].values)
plt.ylabel("Total Attack", fontsize=18)
plt.xticks(rotation=90)
plt.xlabel("Attack Group", fontsize=18)
plt.title("Attacks Group", size=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Attacks Group')

# %% [markdown]
# # Conclusion

# %% [markdown]
# Iraq is ranked first on Global Terrorism activity followed by Pakistan, Afganistan, India etc...
#
# Middle East & North Africa is the region with most attacks.
#
# Most targeted areas are private citizens and infrastructure, military, police etc...
#
# Global Terror attacks rose sharply since 2012
#
# Year with most terrorist attacks: 2014
#
# Most attack types: Bombing/Explosion
#
# Taliban is the known group with most attacks.
